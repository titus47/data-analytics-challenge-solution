# %%
import pandas as pd

json = pd.read_json('https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')
json.head(711)
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 0          no                  community    Haruna Mohammed        year_round
# 1          no                  community     Haruna Mohmmed        year_round
# 2          no                  community    Haruna Mohammed        year_round
# 3          no                  community    Haruna Mohammed        year_round
# 4          no                  community    Haruna Mohammed        year_round
# ..        ...                        ...                ...               ...
# 706        no  local_authority community         Emmanuel y        year_round
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
#
# ...

# %%
import pandas as pd

json = pd.read_json('https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')
(json['water_point_condition'] == 'functioning').sum()
# Out:
# 590

# %%
import pandas as pd

json = pd.read_json('https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')
json.groupby("communities_villages")['water_point_condition'].count()
# Out:
# communities_villages
# Abanyeri        4
# Akpari-yeri     3
# Alavanyo        3
# Arigu          12
# Badomsa        27
#                ..
# Zogsa           6
# Zua            28
# Zuedema        18
# Zukpeni         6
# Zundem         30
# Name: water_point_condition, Length: 65, dtype: int64

# %%
import pandas as pd

json = pd.read_json('https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')
json[['communities_villages', 'water_functioning']]
df = (json['water_point_condition'] == 'broken').mean()
df * 100
# Out:
# 5.617977528089887
